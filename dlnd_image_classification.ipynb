# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 100
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 100:
# Image - Min Value: 30 Max Value: 242
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    return (x/255.)
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return (np.eye(10)[x])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
print (valid_features.shape)
# Out:
# (5000, 32, 32, 3)

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    #print (image_shape)
    return  (tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name="x"))


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    #print (n_classes)
    return (tf.placeholder(tf.float32, shape=[None, n_classes],name="y"))


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return (tf.placeholder(tf.float32,name="keep_prob"))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# (32, 32, 3)
# Image Input Tests Passed.
# 10
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    
    # TODO: Implement Function    
    height = conv_ksize[0]
    width = conv_ksize[1]
    input_depth = int(x_tensor.shape[3])
       
    weight = tf.Variable(tf.truncated_normal([height, width, input_depth,conv_num_outputs], stddev=0.05))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    x = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x = tf.nn.bias_add(x, bias)
    x = tf.nn.relu(x)
        
    return tf.nn.max_pool(
        x,
        ksize=[1, pool_ksize[0], pool_ksize[1], 1],
        strides=[1, pool_strides[0], pool_strides[1], 1],
        padding='SAME')
    
    
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    # shape of x_tensor =[None, image_height, image_width, input_depth])
    flattened_image_size = int(x_tensor.shape[1])*int(x_tensor.shape[2])*int(x_tensor.shape[3])
    
    result = tf.reshape(x_tensor, [-1, flattened_image_size])
    print('reshape:',x_tensor.shape,'->',result.shape)
    return result

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# reshape: (?, 10, 30, 6) -> (?, 1800)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([int(x_tensor.shape[1]), num_outputs], stddev=0.05))
    biases = tf.Variable(tf.zeros(num_outputs))    
    return tf.add(tf.matmul(x_tensor, weights), biases)
                     
   

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    
    conv_num_outputs = (6,16)
    conv_ksize = (3,3)
    conv_strides = (1,1)
    pool_ksize = (2,2)
    pool_strides = (2,2)
    #print ("x = ",x.shape)
    
    c1s2 = conv2d_maxpool(x,conv_num_outputs[0], conv_ksize, conv_strides, pool_ksize, pool_strides)
    #print("c1s2 = ",c1s2.shape)
    
    #layer 2
    c3s4 = conv2d_maxpool(c1s2,conv_num_outputs[1],conv_ksize, conv_strides,pool_ksize, pool_strides)
    
    #print ("c3s4 = ",c3s4.shape)
        
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    s5 = flatten(c3s4)               
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    c6 = fully_conn(s5, 120)
    f7 = fully_conn(c6,84)
    
    f7_drop = tf.nn.dropout(f7, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(f7_drop,10)

    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (32, 32, 3)
# 10
# reshape: (?, 8, 8, 16) -> (?, 1024)
# reshape: (?, 8, 8, 16) -> (?, 1024)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    #print ("batch_features =",feature_batch.shape)
    #print ("batch_labels =",label_batch.shape)
    #print ("keep_probability", keep_probability)
    #print (optimizer)
    #print(session)
            
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability})
    
    
        

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    print ("loss =",loss)
    
    valid_acc = session.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    print ("valid accuracy =",valid_acc)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss = 2.25092
# valid accuracy = 0.2212
# Epoch  2, CIFAR-10 Batch 1:  loss = 2.21481
# valid accuracy = 0.2808
# Epoch  3, CIFAR-10 Batch 1:  loss = 2.11302
# valid accuracy = 0.3412
# Epoch  4, CIFAR-10 Batch 1:  loss = 2.00699
# valid accuracy = 0.376
# Epoch  5, CIFAR-10 Batch 1:  loss = 1.94698
# valid accuracy = 0.3852
# Epoch  6, CIFAR-10 Batch 1:  loss = 1.90371
# valid accuracy = 0.4078
# Epoch  7, CIFAR-10 Batch 1:  loss = 1.8648
# valid accuracy = 0.42
# Epoch  8, CIFAR-10 Batch 1:  loss = 1.85746
# valid accuracy = 0.426
# Epoch  9, CIFAR-10 Batch 1:  loss = 1.7868
# valid accuracy = 0.4276
# Epoch 10, CIFAR-10 Batch 1:  loss = 1.76968
# valid accuracy = 0.4344
# Epoch 11, CIFAR-10 Batch 1:  loss = 1.6933
# valid accuracy = 0.44
# Epoch 12, CIFAR-10 Batch 1:  loss = 1.64555
# valid accuracy = 0.4458
# Epoch 13, CIFAR-10 Batch 1:  loss = 1.57495
# valid accuracy = 0.4596
# Epoch 14, CIFAR-10 Batch 1:  loss = 1.54526
# valid accuracy = 0.459
# Epoch 15, CIFAR-10 Batch 1:  loss = 1.54914
# valid accuracy = 0.4586
# Epoch 16, CIFAR-10 Batch 1:  loss = 1.47917
# valid accuracy = 0.465
# Epoch 17, CIFAR-10 Batch 1:  loss = 1.3987
# valid accuracy = 0.4736
# Epoch 18, CIFAR-10 Batch 1:  loss = 1.36026
# valid accuracy = 0.4768
# Epoch 19, CIFAR-10 Batch 1:  loss = 1.3258
# valid accuracy = 0.4826
# Epoch 20, CIFAR-10 Batch 1:  loss = 1.30491
# valid accuracy = 0.4898
# Epoch 21, CIFAR-10 Batch 1:  loss = 1.23981
# valid accuracy = 0.4946
# Epoch 22, CIFAR-10 Batch 1:  loss = 1.12453
# valid accuracy = 0.5024
# Epoch 23, CIFAR-10 Batch 1:  loss = 1.198
# valid accuracy = 0.4912
# Epoch 24, CIFAR-10 Batch 1:  loss = 1.17053
# valid accuracy = 0.4954
# Epoch 25, CIFAR-10 Batch 1:  loss = 1.08941
# valid accuracy = 0.4986
# Epoch 26, CIFAR-10 Batch 1:  loss = 0.996417
# valid accuracy = 0.5078
# Epoch 27, CIFAR-10 Batch 1:  loss = 0.982051
# valid accuracy = 0.5094
# Epoch 28, CIFAR-10 Batch 1:  loss = 0.924478
# valid accuracy = 0.5182
# Epoch 29, CIFAR-10 Batch 1:  loss = 0.89878
# valid accuracy = 0.519
# Epoch 30, CIFAR-10 Batch 1:  loss = 0.888758
# valid accuracy = 0.5138
# Epoch 31, CIFAR-10 Batch 1:  loss = 0.83906
# valid accuracy = 0.516
# Epoch 32, CIFAR-10 Batch 1:  loss = 0.789806
# valid accuracy = 0.524
# Epoch 33, CIFAR-10 Batch 1:  loss = 0.753468
# valid accuracy = 0.5268
# Epoch 34, CIFAR-10 Batch 1:  loss = 0.747039
# valid accuracy = 0.533
# Epoch 35, CIFAR-10 Batch 1:  loss = 0.718348
# valid accuracy = 0.5238
# Epoch 36, CIFAR-10 Batch 1:  loss = 0.655945
# valid accuracy = 0.5322
# Epoch 37, CIFAR-10 Batch 1:  loss = 0.615865
# valid accuracy = 0.5246
# Epoch 38, CIFAR-10 Batch 1:  loss = 0.613502
# valid accuracy = 0.5322
# Epoch 39, CIFAR-10 Batch 1:  loss = 0.568388
# valid accuracy = 0.5302
# Epoch 40, CIFAR-10 Batch 1:  loss = 0.530335
# valid accuracy = 0.5344
# Epoch 41, CIFAR-10 Batch 1:  loss = 0.50616
# valid accuracy = 0.5332
# Epoch 42, CIFAR-10 Batch 1:  loss = 0.510947
# valid accuracy = 0.5276
# Epoch 43, CIFAR-10 Batch 1:  loss = 0.486027
# valid accuracy = 0.5254
# Epoch 44, CIFAR-10 Batch 1:  loss = 0.424059
# valid accuracy = 0.5382
# Epoch 45, CIFAR-10 Batch 1:  loss = 0.440809
# valid accuracy = 0.535
# Epoch 46, CIFAR-10 Batch 1:  loss = 0.455734
# valid accuracy = 0.52
# Epoch 47, CIFAR-10 Batch 1:  loss = 0.445096
# valid accuracy = 0.5144
# Epoch 48, CIFAR-10 Batch 1:  loss = 0.434287
# valid accuracy = 0.514
# Epoch 49, CIFAR-10 Batch 1:  loss = 0.405348
# valid accuracy = 0.5176
# Epoch 50, CIFAR-10 Batch 1:  loss = 0.347521
# valid accuracy = 0.5276

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss = 2.18729
# valid accuracy = 0.2478
# Epoch  1, CIFAR-10 Batch 2:  loss = 2.03403
# valid accuracy = 0.2866
# Epoch  1, CIFAR-10 Batch 3:  loss = 1.69251
# valid accuracy = 0.3364
# Epoch  1, CIFAR-10 Batch 4:  loss = 1.68453
# valid accuracy = 0.3582
# Epoch  1, CIFAR-10 Batch 5:  loss = 1.77944
# valid accuracy = 0.3746
# Epoch  2, CIFAR-10 Batch 1:  loss = 1.94719
# valid accuracy = 0.392
# Epoch  2, CIFAR-10 Batch 2:  loss = 1.76129
# valid accuracy = 0.416
# Epoch  2, CIFAR-10 Batch 3:  loss = 1.49342
# valid accuracy = 0.4012
# Epoch  2, CIFAR-10 Batch 4:  loss = 1.57846
# valid accuracy = 0.4352
# Epoch  2, CIFAR-10 Batch 5:  loss = 1.5963
# valid accuracy = 0.4436
# Epoch  3, CIFAR-10 Batch 1:  loss = 1.7863
# valid accuracy = 0.4482
# Epoch  3, CIFAR-10 Batch 2:  loss = 1.46645
# valid accuracy = 0.4414
# Epoch  3, CIFAR-10 Batch 3:  loss = 1.33668
# valid accuracy = 0.4566
# Epoch  3, CIFAR-10 Batch 4:  loss = 1.46092
# valid accuracy = 0.4736
# Epoch  3, CIFAR-10 Batch 5:  loss = 1.46203
# valid accuracy = 0.4734
# Epoch  4, CIFAR-10 Batch 1:  loss = 1.63311
# valid accuracy = 0.482
# Epoch  4, CIFAR-10 Batch 2:  loss = 1.39206
# valid accuracy = 0.4716
# Epoch  4, CIFAR-10 Batch 3:  loss = 1.26317
# valid accuracy = 0.479
# Epoch  4, CIFAR-10 Batch 4:  loss = 1.37321
# valid accuracy = 0.4966
# Epoch  4, CIFAR-10 Batch 5:  loss = 1.41603
# valid accuracy = 0.4984
# Epoch  5, CIFAR-10 Batch 1:  loss = 1.52921
# valid accuracy = 0.501
# Epoch  5, CIFAR-10 Batch 2:  loss = 1.29984
# valid accuracy = 0.5054
# Epoch  5, CIFAR-10 Batch 3:  loss = 1.15476
# valid accuracy = 0.4998
# Epoch  5, CIFAR-10 Batch 4:  loss = 1.27255
# valid accuracy = 0.5128
# Epoch  5, CIFAR-10 Batch 5:  loss = 1.39552
# valid accuracy = 0.513
# Epoch  6, CIFAR-10 Batch 1:  loss = 1.4476
# valid accuracy = 0.5226
# Epoch  6, CIFAR-10 Batch 2:  loss = 1.22727
# valid accuracy = 0.5186
# Epoch  6, CIFAR-10 Batch 3:  loss = 1.07281
# valid accuracy = 0.5248
# Epoch  6, CIFAR-10 Batch 4:  loss = 1.19748
# valid accuracy = 0.5336
# Epoch  6, CIFAR-10 Batch 5:  loss = 1.32379
# valid accuracy = 0.5314
# Epoch  7, CIFAR-10 Batch 1:  loss = 1.41609
# valid accuracy = 0.5318
# Epoch  7, CIFAR-10 Batch 2:  loss = 1.198
# valid accuracy = 0.539
# Epoch  7, CIFAR-10 Batch 3:  loss = 0.976002
# valid accuracy = 0.5358
# Epoch  7, CIFAR-10 Batch 4:  loss = 1.16877
# valid accuracy = 0.541
# Epoch  7, CIFAR-10 Batch 5:  loss = 1.26513
# valid accuracy = 0.5408
# Epoch  8, CIFAR-10 Batch 1:  loss = 1.29291
# valid accuracy = 0.5568
# Epoch  8, CIFAR-10 Batch 2:  loss = 1.10422
# valid accuracy = 0.5536
# Epoch  8, CIFAR-10 Batch 3:  loss = 0.961994
# valid accuracy = 0.5448
# Epoch  8, CIFAR-10 Batch 4:  loss = 1.09908
# valid accuracy = 0.5562
# Epoch  8, CIFAR-10 Batch 5:  loss = 1.26069
# valid accuracy = 0.5442
# Epoch  9, CIFAR-10 Batch 1:  loss = 1.19652
# valid accuracy = 0.5686
# Epoch  9, CIFAR-10 Batch 2:  loss = 1.04848
# valid accuracy = 0.5664
# Epoch  9, CIFAR-10 Batch 3:  loss = 0.912491
# valid accuracy = 0.561
# Epoch  9, CIFAR-10 Batch 4:  loss = 1.06098
# valid accuracy = 0.5676
# Epoch  9, CIFAR-10 Batch 5:  loss = 1.16027
# valid accuracy = 0.5404
# Epoch 10, CIFAR-10 Batch 1:  loss = 1.14965
# valid accuracy = 0.5764
# Epoch 10, CIFAR-10 Batch 2:  loss = 0.976369
# valid accuracy = 0.5768
# Epoch 10, CIFAR-10 Batch 3:  loss = 0.834259
# valid accuracy = 0.5648
# Epoch 10, CIFAR-10 Batch 4:  loss = 0.970219
# valid accuracy = 0.5766
# Epoch 10, CIFAR-10 Batch 5:  loss = 1.04412
# valid accuracy = 0.5688
# Epoch 11, CIFAR-10 Batch 1:  loss = 1.01051
# valid accuracy = 0.5848
# Epoch 11, CIFAR-10 Batch 2:  loss = 0.943042
# valid accuracy = 0.586
# Epoch 11, CIFAR-10 Batch 3:  loss = 0.816582
# valid accuracy = 0.5756
# Epoch 11, CIFAR-10 Batch 4:  loss = 0.888672
# valid accuracy = 0.5864
# Epoch 11, CIFAR-10 Batch 5:  loss = 0.982318
# valid accuracy = 0.5784
# Epoch 12, CIFAR-10 Batch 1:  loss = 0.995324
# valid accuracy = 0.5982
# Epoch 12, CIFAR-10 Batch 2:  loss = 0.896726
# valid accuracy = 0.5992
# Epoch 12, CIFAR-10 Batch 3:  loss = 0.756612
# valid accuracy = 0.584
# Epoch 12, CIFAR-10 Batch 4:  loss = 0.829783
# valid accuracy = 0.594
# Epoch 12, CIFAR-10 Batch 5:  loss = 0.914524
# valid accuracy = 0.5666
# Epoch 13, CIFAR-10 Batch 1:  loss = 0.968279
# valid accuracy = 0.6084
# Epoch 13, CIFAR-10 Batch 2:  loss = 0.851186
# valid accuracy = 0.5982
# Epoch 13, CIFAR-10 Batch 3:  loss = 0.747633
# valid accuracy = 0.5934
# Epoch 13, CIFAR-10 Batch 4:  loss = 0.79422
# valid accuracy = 0.606
# Epoch 13, CIFAR-10 Batch 5:  loss = 0.810102
# valid accuracy = 0.5846
# Epoch 14, CIFAR-10 Batch 1:  loss = 0.861241
# valid accuracy = 0.6186
# Epoch 14, CIFAR-10 Batch 2:  loss = 0.864368
# valid accuracy = 0.6122
# Epoch 14, CIFAR-10 Batch 3:  loss = 0.716745
# valid accuracy = 0.601
# Epoch 14, CIFAR-10 Batch 4:  loss = 0.781145
# valid accuracy = 0.6092
# Epoch 14, CIFAR-10 Batch 5:  loss = 0.733272
# valid accuracy = 0.5994
# Epoch 15, CIFAR-10 Batch 1:  loss = 0.821685
# valid accuracy = 0.6176
# Epoch 15, CIFAR-10 Batch 2:  loss = 0.78623
# valid accuracy = 0.609
# Epoch 15, CIFAR-10 Batch 3:  loss = 0.699021
# valid accuracy = 0.6062
# Epoch 15, CIFAR-10 Batch 4:  loss = 0.690618
# valid accuracy = 0.6272
# Epoch 15, CIFAR-10 Batch 5:  loss = 0.720401
# valid accuracy = 0.597
# Epoch 16, CIFAR-10 Batch 1:  loss = 0.796039
# valid accuracy = 0.6202
# Epoch 16, CIFAR-10 Batch 2:  loss = 0.729497
# valid accuracy = 0.6174
# Epoch 16, CIFAR-10 Batch 3:  loss = 0.681885
# valid accuracy = 0.6102
# Epoch 16, CIFAR-10 Batch 4:  loss = 0.641883
# valid accuracy = 0.6298
# Epoch 16, CIFAR-10 Batch 5:  loss = 0.640837
# valid accuracy = 0.6002
# Epoch 17, CIFAR-10 Batch 1:  loss = 0.802982
# valid accuracy = 0.6224
# Epoch 17, CIFAR-10 Batch 2:  loss = 0.70214
# valid accuracy = 0.6144
# Epoch 17, CIFAR-10 Batch 3:  loss = 0.60473
# valid accuracy = 0.621
# Epoch 17, CIFAR-10 Batch 4:  loss = 0.585181
# valid accuracy = 0.6316
# Epoch 17, CIFAR-10 Batch 5:  loss = 0.626834
# valid accuracy = 0.6116
# Epoch 18, CIFAR-10 Batch 1:  loss = 0.745699
# valid accuracy = 0.6264
# Epoch 18, CIFAR-10 Batch 2:  loss = 0.661436
# valid accuracy = 0.6152
# Epoch 18, CIFAR-10 Batch 3:  loss = 0.590815
# valid accuracy = 0.6238
# Epoch 18, CIFAR-10 Batch 4:  loss = 0.595087
# valid accuracy = 0.6386
# Epoch 18, CIFAR-10 Batch 5:  loss = 0.562643
# valid accuracy = 0.6294
# Epoch 19, CIFAR-10 Batch 1:  loss = 0.721165
# valid accuracy = 0.6186
# Epoch 19, CIFAR-10 Batch 2:  loss = 0.64649
# valid accuracy = 0.6318
# Epoch 19, CIFAR-10 Batch 3:  loss = 0.570874
# valid accuracy = 0.6256
# Epoch 19, CIFAR-10 Batch 4:  loss = 0.554608
# valid accuracy = 0.6426
# Epoch 19, CIFAR-10 Batch 5:  loss = 0.557938
# valid accuracy = 0.6214
# Epoch 20, CIFAR-10 Batch 1:  loss = 0.686664
# valid accuracy = 0.6228
# Epoch 20, CIFAR-10 Batch 2:  loss = 0.607677
# valid accuracy = 0.6228
# Epoch 20, CIFAR-10 Batch 3:  loss = 0.530671
# valid accuracy = 0.6252
# Epoch 20, CIFAR-10 Batch 4:  loss = 0.521547
# valid accuracy = 0.6374
# Epoch 20, CIFAR-10 Batch 5:  loss = 0.518519
# valid accuracy = 0.6192
# Epoch 21, CIFAR-10 Batch 1:  loss = 0.6556
# valid accuracy = 0.628
# Epoch 21, CIFAR-10 Batch 2:  loss = 0.53782
# valid accuracy = 0.6342
# Epoch 21, CIFAR-10 Batch 3:  loss = 0.520427
# valid accuracy = 0.6296
# Epoch 21, CIFAR-10 Batch 4:  loss = 0.477578
# valid accuracy = 0.641
# Epoch 21, CIFAR-10 Batch 5:  loss = 0.474039
# valid accuracy = 0.6328
# Epoch 22, CIFAR-10 Batch 1:  loss = 0.697495
# valid accuracy = 0.6346
# Epoch 22, CIFAR-10 Batch 2:  loss = 0.523925
# valid accuracy = 0.6254
# Epoch 22, CIFAR-10 Batch 3:  loss = 0.499626
# valid accuracy = 0.6292
# Epoch 22, CIFAR-10 Batch 4:  loss = 0.479511
# valid accuracy = 0.6456
# Epoch 22, CIFAR-10 Batch 5:  loss = 0.474792
# valid accuracy = 0.637
# Epoch 23, CIFAR-10 Batch 1:  loss = 0.636422
# valid accuracy = 0.638
# Epoch 23, CIFAR-10 Batch 2:  loss = 0.501121
# valid accuracy = 0.6188
# Epoch 23, CIFAR-10 Batch 3:  loss = 0.472006
# valid accuracy = 0.6304
# Epoch 23, CIFAR-10 Batch 4:  loss = 0.446158
# valid accuracy = 0.6476
# Epoch 23, CIFAR-10 Batch 5:  loss = 0.45289
# valid accuracy = 0.6292
# Epoch 24, CIFAR-10 Batch 1:  loss = 0.636615
# valid accuracy = 0.6402
# Epoch 24, CIFAR-10 Batch 2:  loss = 0.48125
# valid accuracy = 0.6396
# Epoch 24, CIFAR-10 Batch 3:  loss = 0.441264
# valid accuracy = 0.6312
# Epoch 24, CIFAR-10 Batch 4:  loss = 0.442593
# valid accuracy = 0.6426
# Epoch 24, CIFAR-10 Batch 5:  loss = 0.430118
# valid accuracy = 0.6356
# Epoch 25, CIFAR-10 Batch 1:  loss = 0.59785
# valid accuracy = 0.6376
# Epoch 25, CIFAR-10 Batch 2:  loss = 0.43425
# valid accuracy = 0.635
# Epoch 25, CIFAR-10 Batch 3:  loss = 0.42395
# valid accuracy = 0.6442
# Epoch 25, CIFAR-10 Batch 4:  loss = 0.445017
# valid accuracy = 0.6384
# Epoch 25, CIFAR-10 Batch 5:  loss = 0.407074
# valid accuracy = 0.649
# Epoch 26, CIFAR-10 Batch 1:  loss = 0.579902
# valid accuracy = 0.6374
# Epoch 26, CIFAR-10 Batch 2:  loss = 0.446534
# valid accuracy = 0.6378
# Epoch 26, CIFAR-10 Batch 3:  loss = 0.398608
# valid accuracy = 0.6438
# Epoch 26, CIFAR-10 Batch 4:  loss = 0.409427
# valid accuracy = 0.6426
# Epoch 26, CIFAR-10 Batch 5:  loss = 0.41598
# valid accuracy = 0.6494
# Epoch 27, CIFAR-10 Batch 1:  loss = 0.552157
# valid accuracy = 0.6462
# Epoch 27, CIFAR-10 Batch 2:  loss = 0.414449
# valid accuracy = 0.6356
# Epoch 27, CIFAR-10 Batch 3:  loss = 0.378188
# valid accuracy = 0.64
# Epoch 27, CIFAR-10 Batch 4:  loss = 0.401594
# valid accuracy = 0.6346
# Epoch 27, CIFAR-10 Batch 5:  loss = 0.396288
# valid accuracy = 0.651
# Epoch 28, CIFAR-10 Batch 1:  loss = 0.494744
# valid accuracy = 0.646
# Epoch 28, CIFAR-10 Batch 2:  loss = 0.407291
# valid accuracy = 0.6378
# Epoch 28, CIFAR-10 Batch 3:  loss = 0.344565
# valid accuracy = 0.6456
# Epoch 28, CIFAR-10 Batch 4:  loss = 0.391578
# valid accuracy = 0.6376
# Epoch 28, CIFAR-10 Batch 5:  loss = 0.366882
# valid accuracy = 0.6372
# Epoch 29, CIFAR-10 Batch 1:  loss = 0.507592
# valid accuracy = 0.6438
# Epoch 29, CIFAR-10 Batch 2:  loss = 0.369136
# valid accuracy = 0.6428
# Epoch 29, CIFAR-10 Batch 3:  loss = 0.310331
# valid accuracy = 0.6456
# Epoch 29, CIFAR-10 Batch 4:  loss = 0.415474
# valid accuracy = 0.6164
# Epoch 29, CIFAR-10 Batch 5:  loss = 0.375546
# valid accuracy = 0.6444
# Epoch 30, CIFAR-10 Batch 1:  loss = 0.475808
# valid accuracy = 0.6396
# Epoch 30, CIFAR-10 Batch 2:  loss = 0.382482
# valid accuracy = 0.6438
# Epoch 30, CIFAR-10 Batch 3:  loss = 0.338267
# valid accuracy = 0.6442
# Epoch 30, CIFAR-10 Batch 4:  loss = 0.398936
# valid accuracy = 0.6202
# Epoch 30, CIFAR-10 Batch 5:  loss = 0.338181
# valid accuracy = 0.6434
# Epoch 31, CIFAR-10 Batch 1:  loss = 0.511689
# valid accuracy = 0.6364
# Epoch 31, CIFAR-10 Batch 2:  loss = 0.348641
# valid accuracy = 0.6376
# Epoch 31, CIFAR-10 Batch 3:  loss = 0.300332
# valid accuracy = 0.6452
# Epoch 31, CIFAR-10 Batch 4:  loss = 0.352191
# valid accuracy = 0.6322
# Epoch 31, CIFAR-10 Batch 5:  loss = 0.329432
# valid accuracy = 0.6494
# Epoch 32, CIFAR-10 Batch 1:  loss = 0.452273
# valid accuracy = 0.6388
# Epoch 32, CIFAR-10 Batch 2:  loss = 0.359965
# valid accuracy = 0.6428
# Epoch 32, CIFAR-10 Batch 3:  loss = 0.364153
# valid accuracy = 0.6398
# Epoch 32, CIFAR-10 Batch 4:  loss = 0.349987
# valid accuracy = 0.6358
# Epoch 32, CIFAR-10 Batch 5:  loss = 0.323475
# valid accuracy = 0.6464
# Epoch 33, CIFAR-10 Batch 1:  loss = 0.445192
# valid accuracy = 0.638
# Epoch 33, CIFAR-10 Batch 2:  loss = 0.378689
# valid accuracy = 0.6452
# Epoch 33, CIFAR-10 Batch 3:  loss = 0.296611
# valid accuracy = 0.6282
# Epoch 33, CIFAR-10 Batch 4:  loss = 0.34058
# valid accuracy = 0.6372
# Epoch 33, CIFAR-10 Batch 5:  loss = 0.307342
# valid accuracy = 0.646
# Epoch 34, CIFAR-10 Batch 1:  loss = 0.422999
# valid accuracy = 0.6374
# Epoch 34, CIFAR-10 Batch 2:  loss = 0.356786
# valid accuracy = 0.6432
# Epoch 34, CIFAR-10 Batch 3:  loss = 0.278514
# valid accuracy = 0.6304
# Epoch 34, CIFAR-10 Batch 4:  loss = 0.32815
# valid accuracy = 0.631
# Epoch 34, CIFAR-10 Batch 5:  loss = 0.281338
# valid accuracy = 0.646
# Epoch 35, CIFAR-10 Batch 1:  loss = 0.399913
# valid accuracy = 0.6388
# Epoch 35, CIFAR-10 Batch 2:  loss = 0.325226
# valid accuracy = 0.634
# Epoch 35, CIFAR-10 Batch 3:  loss = 0.277437
# valid accuracy = 0.6202
# Epoch 35, CIFAR-10 Batch 4:  loss = 0.318547
# valid accuracy = 0.6382
# Epoch 35, CIFAR-10 Batch 5:  loss = 0.287695
# valid accuracy = 0.6408
# Epoch 36, CIFAR-10 Batch 1:  loss = 0.382241
# valid accuracy = 0.641
# Epoch 36, CIFAR-10 Batch 2:  loss = 0.337269
# valid accuracy = 0.6414
# Epoch 36, CIFAR-10 Batch 3:  loss = 0.252016
# valid accuracy = 0.6312
# Epoch 36, CIFAR-10 Batch 4:  loss = 0.295596
# valid accuracy = 0.6374
# Epoch 36, CIFAR-10 Batch 5:  loss = 0.278391
# valid accuracy = 0.6434
# Epoch 37, CIFAR-10 Batch 1:  loss = 0.376523
# valid accuracy = 0.6358
# Epoch 37, CIFAR-10 Batch 2:  loss = 0.313574
# valid accuracy = 0.633
# Epoch 37, CIFAR-10 Batch 3:  loss = 0.236075
# valid accuracy = 0.6254
# Epoch 37, CIFAR-10 Batch 4:  loss = 0.304362
# valid accuracy = 0.6354
# Epoch 37, CIFAR-10 Batch 5:  loss = 0.282521
# valid accuracy = 0.643
# Epoch 38, CIFAR-10 Batch 1:  loss = 0.39212
# valid accuracy = 0.63
# Epoch 38, CIFAR-10 Batch 2:  loss = 0.262216
# valid accuracy = 0.6306
# Epoch 38, CIFAR-10 Batch 3:  loss = 0.236104
# valid accuracy = 0.6224
# Epoch 38, CIFAR-10 Batch 4:  loss = 0.295141
# valid accuracy = 0.6284
# Epoch 38, CIFAR-10 Batch 5:  loss = 0.205762
# valid accuracy = 0.6402
# Epoch 39, CIFAR-10 Batch 1:  loss = 0.35685
# valid accuracy = 0.6396
# Epoch 39, CIFAR-10 Batch 2:  loss = 0.28909
# valid accuracy = 0.6276
# Epoch 39, CIFAR-10 Batch 3:  loss = 0.230281
# valid accuracy = 0.6382
# Epoch 39, CIFAR-10 Batch 4:  loss = 0.279068
# valid accuracy = 0.6324
# Epoch 39, CIFAR-10 Batch 5:  loss = 0.226728
# valid accuracy = 0.6398
# Epoch 40, CIFAR-10 Batch 1:  loss = 0.324642
# valid accuracy = 0.6392
# Epoch 40, CIFAR-10 Batch 2:  loss = 0.247605
# valid accuracy = 0.6272
# Epoch 40, CIFAR-10 Batch 3:  loss = 0.223946
# valid accuracy = 0.6316
# Epoch 40, CIFAR-10 Batch 4:  loss = 0.265218
# valid accuracy = 0.6332
# Epoch 40, CIFAR-10 Batch 5:  loss = 0.210965
# valid accuracy = 0.6402
# Epoch 41, CIFAR-10 Batch 1:  loss = 0.330367
# valid accuracy = 0.6376
# Epoch 41, CIFAR-10 Batch 2:  loss = 0.265807
# valid accuracy = 0.6242
# Epoch 41, CIFAR-10 Batch 3:  loss = 0.196584
# valid accuracy = 0.6272
# Epoch 41, CIFAR-10 Batch 4:  loss = 0.250117
# valid accuracy = 0.6364
# Epoch 41, CIFAR-10 Batch 5:  loss = 0.216509
# valid accuracy = 0.638
# Epoch 42, CIFAR-10 Batch 1:  loss = 0.304069
# valid accuracy = 0.633
# Epoch 42, CIFAR-10 Batch 2:  loss = 0.260641
# valid accuracy = 0.6204
# Epoch 42, CIFAR-10 Batch 3:  loss = 0.207994
# valid accuracy = 0.6186
# Epoch 42, CIFAR-10 Batch 4:  loss = 0.244574
# valid accuracy = 0.632
# Epoch 42, CIFAR-10 Batch 5:  loss = 0.199442
# valid accuracy = 0.6348
# Epoch 43, CIFAR-10 Batch 1:  loss = 0.302532
# valid accuracy = 0.635
# Epoch 43, CIFAR-10 Batch 2:  loss = 0.273364
# valid accuracy = 0.6224
# Epoch 43, CIFAR-10 Batch 3:  loss = 0.195734
# valid accuracy = 0.6196
# Epoch 43, CIFAR-10 Batch 4:  loss = 0.236918
# valid accuracy = 0.634
# Epoch 43, CIFAR-10 Batch 5:  loss = 0.228506
# valid accuracy = 0.633
# Epoch 44, CIFAR-10 Batch 1:  loss = 0.326276
# valid accuracy = 0.6318
# Epoch 44, CIFAR-10 Batch 2:  loss = 0.255212
# valid accuracy = 0.6158
# Epoch 44, CIFAR-10 Batch 3:  loss = 0.192388
# valid accuracy = 0.6194
# Epoch 44, CIFAR-10 Batch 4:  loss = 0.232996
# valid accuracy = 0.626
# Epoch 44, CIFAR-10 Batch 5:  loss = 0.223954
# valid accuracy = 0.6286
# Epoch 45, CIFAR-10 Batch 1:  loss = 0.323365
# valid accuracy = 0.6348
# Epoch 45, CIFAR-10 Batch 2:  loss = 0.237742
# valid accuracy = 0.6184
# Epoch 45, CIFAR-10 Batch 3:  loss = 0.19404
# valid accuracy = 0.613
# Epoch 45, CIFAR-10 Batch 4:  loss = 0.215203
# valid accuracy = 0.6274
# Epoch 45, CIFAR-10 Batch 5:  loss = 0.212593
# valid accuracy = 0.631
# Epoch 46, CIFAR-10 Batch 1:  loss = 0.332098
# valid accuracy = 0.6264
# Epoch 46, CIFAR-10 Batch 2:  loss = 0.240292
# valid accuracy = 0.6242
# Epoch 46, CIFAR-10 Batch 3:  loss = 0.183724
# valid accuracy = 0.6132
# Epoch 46, CIFAR-10 Batch 4:  loss = 0.214957
# valid accuracy = 0.6256
# Epoch 46, CIFAR-10 Batch 5:  loss = 0.23693
# valid accuracy = 0.6218
# Epoch 47, CIFAR-10 Batch 1:  loss = 0.323404
# valid accuracy = 0.627
# Epoch 47, CIFAR-10 Batch 2:  loss = 0.236854
# valid accuracy = 0.6198
# Epoch 47, CIFAR-10 Batch 3:  loss = 0.187767
# valid accuracy = 0.6172
# Epoch 47, CIFAR-10 Batch 4:  loss = 0.230399
# valid accuracy = 0.6112
# Epoch 47, CIFAR-10 Batch 5:  loss = 0.2324
# valid accuracy = 0.622
# Epoch 48, CIFAR-10 Batch 1:  loss = 0.296478
# valid accuracy = 0.6276
# Epoch 48, CIFAR-10 Batch 2:  loss = 0.23449
# valid accuracy = 0.6224
# Epoch 48, CIFAR-10 Batch 3:  loss = 0.184421
# valid accuracy = 0.6108
# Epoch 48, CIFAR-10 Batch 4:  loss = 0.230531
# valid accuracy = 0.6154
# Epoch 48, CIFAR-10 Batch 5:  loss = 0.224971
# valid accuracy = 0.6166
# Epoch 49, CIFAR-10 Batch 1:  loss = 0.295086
# valid accuracy = 0.6208
# Epoch 49, CIFAR-10 Batch 2:  loss = 0.274761
# valid accuracy = 0.6104
# Epoch 49, CIFAR-10 Batch 3:  loss = 0.160095
# valid accuracy = 0.6118
# Epoch 49, CIFAR-10 Batch 4:  loss = 0.21608
# valid accuracy = 0.6172
# Epoch 49, CIFAR-10 Batch 5:  loss = 0.241023
# valid accuracy = 0.6102
# Epoch 50, CIFAR-10 Batch 1:  loss = 0.335582
# valid accuracy = 0.6168
# Epoch 50, CIFAR-10 Batch 2:  loss = 0.250881
# valid accuracy = 0.6128
# Epoch 50, CIFAR-10 Batch 3:  loss = 0.154928
# valid accuracy = 0.6096
# Epoch 50, CIFAR-10 Batch 4:  loss = 0.203448
# valid accuracy = 0.6238
# Epoch 50, CIFAR-10 Batch 5:  loss = 0.246198
# valid accuracy = 0.6084

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6112539556962026

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
